# %%
from pathlib import Path

import os
import xmltodict
from matplotlib import pyplot as plt
import splitfolders
import numpy as np
from sklearn.model_selection import train_test_split
import shutil

# %% [markdown]
# # Part 0: Set User-Defined Parameters

# %%
# Dataset Cropping Parameters
path_to_dataset = './original_fish_dataset'
target_cropped_dataset_root = './dataset_cropped'
target_uncropped_dataset_root = './dataset_uncropped'

# Dataset Splitting Parameters
split_cropped_dataset_root = './dataset_cropped_split'
split_uncropped_dataset_root = './dataset_uncropped_split'
train_dataset_split_size = 0.8
val_dataset_split_size = 0.1
test_dataset_split_size = 0.1

# %%
path_to_herring_root = os.path.join(path_to_dataset, 'Herring')
path_to_non_herring_root = os.path.join(path_to_dataset, 'Non-herring')

path_to_herring_images = os.path.join(path_to_herring_root, 'Images')
path_to_herring_data = os.path.join(path_to_herring_root, 'Xml')

path_to_non_herring_images = os.path.join(path_to_non_herring_root, 'Images')
path_to_non_herring_data = os.path.join(path_to_non_herring_root, 'Xml')

# %% [markdown]
# # Part 1: Create Correctly-Formatted Datasets From Original Images

# %%
# Cropped Dataset creation
fish_counter = {}

def crop_fish(image, xmin, xmax, ymin, ymax, fish_type):
    xmin = int(xmin)
    xmax = int(xmax)
    ymin = int(ymin)
    ymax = int(ymax)
    cropped_fish = image[ymin:ymax, xmin:xmax]
    save_img_target_dir = os.path.join(target_cropped_dataset_root, fish_type, 'images')
    save_data_target_dir = os.path.join(target_cropped_dataset_root, fish_type, 'labels')
    os.makedirs(save_img_target_dir, exist_ok=True)
    os.makedirs(save_data_target_dir, exist_ok=True)

    if fish_type not in fish_counter:
        fish_counter[fish_type] = 0
    else:
        fish_counter[fish_type] += 1

    file_name = str(fish_counter[fish_type])
    plt.imsave(os.path.join(save_img_target_dir, file_name+'.png'), cropped_fish)
    with open(os.path.join(save_data_target_dir, file_name+'.txt'), 'w+') as f:
        f.write(f"{fish_type} {(xmax-xmin)//2} {(ymax-ymin)//2} {xmax-xmin} {ymax-ymin}")
        f.close()

for img_root, data_root in [(path_to_non_herring_images, path_to_non_herring_data), (path_to_herring_images, path_to_herring_data)]:
    for file_obj in Path(img_root).iterdir():
        if file_obj.is_file():
            data_file_path = os.path.join(data_root, file_obj.stem+".xml")
            if not Path(data_file_path).is_file():
                continue

            with open(data_file_path, 'r') as xml_file:
                annotations = xmltodict.parse(xml_file.read())['annotation']

            img = plt.imread(file_obj).astype(float)

            if 'object' not in annotations:
                continue
            try:
                if type(annotations['object']) == list:
                    for fa in annotations['object']:
                        fish_type = fa['fish-type'].replace(' ', '-')
                        crop_fish(img, fa['bndbox']['xmin'], fa['bndbox']['xmax'], fa['bndbox']['ymin'], fa['bndbox']['ymax'], fish_type)
                else:
                    fa = annotations['object']
                    fish_type = fa['fish-type'].replace(' ', '-')
                    crop_fish(img, fa['bndbox']['xmin'], fa['bndbox']['xmax'], fa['bndbox']['ymin'], fa['bndbox']['ymax'], fish_type)
            except Exception as e:
                print(f"Caught Error {e}")
# Out:
# Caught Error zero-size array to reduction operation maximum which has no identity
# Caught Error zero-size array to reduction operation maximum which has no identity
# Caught Error zero-size array to reduction operation maximum which has no identity

# %%
# Uncropped Dataset Creation
fish_counter = {}

for img_root, data_root in [(path_to_non_herring_images, path_to_non_herring_data), (path_to_herring_images, path_to_herring_data)]:
    for file_obj in Path(img_root).iterdir():
        if file_obj.is_file():

            data_file_path = os.path.join(data_root, file_obj.stem+".xml")

            # if data_file_path == './original_fish_dataset/Non-herring/Xml/201503.20150517.215226032.49000_01_02.xml':
            #     print("Hi!")

            if not Path(data_file_path).is_file():
                continue

            with open(data_file_path, 'r') as xml_file:
                annotations = xmltodict.parse(xml_file.read())['annotation']


            save_img_target_dir = os.path.join(target_uncropped_dataset_root, 'ErrorFish', 'images')
            save_data_target_dir = os.path.join(target_uncropped_dataset_root, 'ErrorFish', 'labels')
            file_name = "ErrorFish"
            fish_counter["ErrorFish"] = -1

            if 'object' not in annotations:
                continue
            try:
                if type(annotations['object']) == list:
                    lines = []
                    first = True
                    if len(annotations['object']) == 0:
                        continue

                    for fa in annotations['object']:
                        fish_type = fa['fish-type'].replace(' ', '-')

                        if first:
                            first = False
                            if fish_type not in fish_counter:
                                fish_counter[fish_type] = 0
                            else:
                                fish_counter[fish_type] += 1

                        save_img_target_dir = os.path.join(target_uncropped_dataset_root, fish_type, 'images')
                        save_data_target_dir = os.path.join(target_uncropped_dataset_root, fish_type, 'labels')

                        xmin = int(fa['bndbox']['xmin'])
                        xmax = int(fa['bndbox']['xmax'])
                        ymin = int(fa['bndbox']['ymin'])
                        ymax = int(fa['bndbox']['ymax'])

                        os.makedirs(save_img_target_dir, exist_ok=True)
                        os.makedirs(save_data_target_dir, exist_ok=True)

                        file_name = str(fish_counter[fish_type])
                        lines.append(f"{fish_type} {(xmax-xmin)//2} {(ymax-ymin)//2} {xmax-xmin} {ymax-ymin}\n")

                    if len(lines) > 0:
                        lines[-1] = lines[-1][:-1]  # Remove newline at end of file
                        with open(os.path.join(save_data_target_dir, file_name+'.txt'), 'w+') as f:
                            f.writelines(lines)
                            f.close()

                else:
                    fa = annotations['object']
                    fish_type = fa['fish-type'].replace(' ', '-')

                    if fish_type not in fish_counter:
                        fish_counter[fish_type] = 0
                    else:
                        fish_counter[fish_type] += 1

                    save_img_target_dir = os.path.join(target_uncropped_dataset_root, fish_type, 'images')
                    save_data_target_dir = os.path.join(target_uncropped_dataset_root, fish_type, 'labels')

                    xmin = int(fa['bndbox']['xmin'])
                    xmax = int(fa['bndbox']['xmax'])
                    ymin = int(fa['bndbox']['ymin'])
                    ymax = int(fa['bndbox']['ymax'])

                    os.makedirs(save_img_target_dir, exist_ok=True)
                    os.makedirs(save_data_target_dir, exist_ok=True)

                    file_name = str(fish_counter[fish_type])

                    with open(os.path.join(save_data_target_dir, file_name+'.txt'), 'w+') as f:
                        f.write(f"{fish_type} {(xmax-xmin)//2} {(ymax-ymin)//2} {xmax-xmin} {ymax-ymin}")
                        f.close()
            except Exception as e:
                print(f"Caught {type(e)}: {e}")

            os.makedirs(save_img_target_dir, exist_ok=True)
            os.makedirs(save_data_target_dir, exist_ok=True)

            img = plt.imread(file_obj).astype(float)
            plt.imsave(os.path.join(save_img_target_dir, file_name+'.png'), img)
# Out:
# Caught <class 'KeyError'>: 'dead-scallop'
# Caught <class 'KeyError'>: 'dead-scallop'
# Caught <class 'KeyError'>: 'dead-scallop'
# Caught <class 'KeyError'>: 'dead-scallop'

# %% [markdown]
# # Part 2: Splitting Dataset Into Train/Val/Test Sets

# %%
def create_split_dataset(unsplit_dataset_root, split_dataset_root):
    def split_fish_class_on_indices(indices, class_name, split_name):
        save_img_target_dir = os.path.join(class_name, 'images/')
        save_data_target_dir = os.path.join(class_name, 'labels/')

        target_split_folder = os.path.join(split_dataset_root, split_name, Path(class_name).name)
        target_split_folder_image_root = os.path.join(target_split_folder, 'images/')
        target_split_folder_data_root = os.path.join(target_split_folder, 'labels/')

        os.makedirs(target_split_folder_image_root, exist_ok=True)
        os.makedirs(target_split_folder_data_root, exist_ok=True)

        for index in indices:
            try:
                shutil.copy(save_img_target_dir+str(index)+'.png', target_split_folder_image_root)
                shutil.copy(save_data_target_dir+str(index)+'.txt', target_split_folder_data_root)
            except:
                print(f"Unable To Copy {class_name} for {index}.png/txt")
                continue

    for fish_type in Path(unsplit_dataset_root).iterdir():
        if fish_type.is_dir():
            fish_images_path = os.path.join(fish_type, 'images')
            num_fish_images = len([x for x in os.listdir(fish_images_path) if x[-4:] == '.png'])
            fish_indices = np.arange(num_fish_images)
            train_indices, val_test_indices = train_test_split(
                fish_indices,
                train_size=train_dataset_split_size,
                random_state=1337
            )
            val_indices, test_indices  = train_test_split(
                val_test_indices,
                train_size=val_dataset_split_size/(val_dataset_split_size+test_dataset_split_size),
                random_state=1338
            )
            split_fish_class_on_indices(train_indices, fish_type, 'train')
            split_fish_class_on_indices(val_indices, fish_type, 'val')
            split_fish_class_on_indices(test_indices, fish_type, 'test')

# %%
# Create Split Dataset For Cropped Images
create_split_dataset(target_cropped_dataset_root, split_cropped_dataset_root)
# Out:
# Unable To Copy dataset_cropped/roundfish for 1750.png/txt
# Unable To Copy dataset_cropped/roundfish for 1695.png/txt
# Unable To Copy dataset_cropped/roundfish for 2958.png/txt

# %%
# Create Split Dataset For Uncropped Images
create_split_dataset(target_uncropped_dataset_root, split_uncropped_dataset_root)
# Out:
# Unable To Copy dataset_uncropped/scallop for 964.png/txt
# Unable To Copy dataset_uncropped/scallop for 554.png/txt
# Unable To Copy dataset_uncropped/scallop for 369.png/txt
# Unable To Copy dataset_uncropped/scallop for 1393.png/txt
# Unable To Copy dataset_uncropped/scallop for 1260.png/txt
# Unable To Copy dataset_uncropped/scallop for 853.png/txt
# Unable To Copy dataset_uncropped/scallop for 418.png/txt
# Unable To Copy dataset_uncropped/scallop for 1069.png/txt
# Unable To Copy dataset_uncropped/scallop for 496.png/txt
# Unable To Copy dataset_uncropped/scallop for 474.png/txt
# Unable To Copy dataset_uncropped/scallop for 178.png/txt
# Unable To Copy dataset_uncropped/scallop for 648.png/txt
# Unable To Copy dataset_uncropped/scallop for 466.png/txt
# Unable To Copy dataset_uncropped/scallop for 733.png/txt
# Unable To Copy dataset_uncropped/scallop for 250.png/txt
# Unable To Copy dataset_uncropped/scallop for 56.png/txt
# Unable To Copy dataset_uncropped/scallop for 273.png/txt
# Unable To Copy dataset_uncropped/scallop for 505.png/txt
# Unable To Copy dataset_uncropped/scallop for 148.png/txt
# Unable To Copy dataset_uncropped/scallop for 736.png/txt
# Unable To Copy dataset_uncropped/scallop for 1013.png/txt
# Unable To Copy dataset_uncropped/scallop for 127.png/txt
# Unable To Copy dataset_uncropped/scallop for 986.png/txt
# Unable To Copy dataset_uncropped/scallop for 386.png/txt
# Unable To Copy dataset_uncropped/scallop for 598.png/txt
# Unable To Copy dataset_uncropped/scallop for 1318.png/txt
# Unable To Copy dataset_uncropped/scallop for 747.png/txt
# Unable To Copy dataset_uncropped/scallop for 1184.png/txt
# Unable To Copy dataset_uncropped/scallop for 50.png/txt
# Unable To Copy dataset_uncropped/scallop for 1303.png/txt
# Unable To Copy dataset_uncropped/scallop for 1330.png/txt
# Unable To Copy dataset_uncropped/scallop for 1282.png/txt
# Unable To Copy dataset_uncropped/scallop for 73.png/txt
# Unable To Copy dataset_uncropped/scallop for 557.png/txt
# Unable To Copy dataset_uncropped/scallop for 1200.png/txt
# Unable To Copy dataset_uncropped/scallop for 140.png/txt
# Unable To Copy dataset_uncropped/scallop for 1171.png/txt
# Unable To Copy dataset_uncropped/scallop for 323.png/txt
# Unable To Copy dataset_uncropped/scallop for 1062.png/txt
# Unable To Copy dataset_uncropped/scallop for 532.png/txt
# Unable To Copy dataset_uncropped/scallop for 329.png/txt
# Unable To Copy dataset_uncropped/scallop for 694.png/txt
# Unable To Copy dataset_uncropped/scallop for 1379.png/txt
# Unable To Copy dataset_uncropped/scallop for 1205.png/txt
# Unable To Copy dataset_uncropped/scallop for 654.png/txt
# Unable To Copy dataset_uncropped/scallop for 730.png/txt
# Unable To Copy dataset_uncropped/scallop for 1253.png/txt
# Unable To Copy dataset_uncropped/scallop for 1026.png/txt
# Unable To Copy dataset_uncropped/scallop for 538.png/txt
# Unable To Copy dataset_uncropped/scallop for 163.png/txt
# Unable To Copy dataset_uncropped/scallop for 977.png/txt
# Unable To Copy dataset_uncropped/scallop for 1328.png/txt
# Unable To Copy dataset_uncropped/scallop for 1409.png/txt
# Unable To Copy dataset_uncropped/scallop for 26.png/txt
# Unable To Copy dataset_uncropped/scallop for 1426.png/txt
# Unable To Copy dataset_uncropped/scallop for 905.png/txt
# Unable To Copy dataset_uncropped/scallop for 904.png/txt
# Unable To Copy dataset_uncropped/scallop for 1096.png/txt
# Unable To Copy dataset_uncropped/scallop for 855.png/txt
# Unable To Copy dataset_uncropped/scallop for 1059.png/txt
# Unable To Copy dataset_uncropped/scallop for 1280.png/txt
# Unable To Copy dataset_uncropped/scallop for 1177.png/txt
# Unable To Copy dataset_uncropped/scallop for 227.png/txt
# Unable To Copy dataset_uncropped/scallop for 225.png/txt
# Unable To Copy dataset_uncropped/scallop for 803.png/txt
# Unable To Copy dataset_uncropped/scallop for 256.png/txt
# Unable To Copy dataset_uncropped/scallop for 1239.png/txt
# Unable To Copy dataset_uncropped/scallop for 343.png/txt
# Unable To Copy dataset_uncropped/scallop for 640.png/txt
# Unable To Copy dataset_uncropped/scallop for 831.png/txt
# Unable To Copy dataset_uncropped/scallop for 613.png/txt
# Unable To Copy dataset_uncropped/scallop for 385.png/txt
# Unable To Copy dataset_uncropped/scallop for 470.png/txt
# Unable To Copy dataset_uncropped/scallop for 821.png/txt
# Unable To Copy dataset_uncropped/scallop for 724.png/txt
# Unable To Copy dataset_uncropped/scallop for 642.png/txt
# Unable To Copy dataset_uncropped/scallop for 671.png/txt
# Unable To Copy dataset_uncropped/scallop for 1129.png/txt
# Unable To Copy dataset_uncropped/scallop for 1312.png/txt
# Unable To Copy dataset_uncropped/scallop for 1036.png/txt
# Unable To Copy dataset_uncropped/scallop for 270.png/txt
# Unable To Copy dataset_uncropped/scallop for 403.png/txt
# Unable To Copy dataset_uncropped/scallop for 41.png/txt
# Unable To Copy dataset_uncropped/scallop for 765.png/txt
# Unable To Copy dataset_uncropped/scallop for 1229.png/txt
# Unable To Copy dataset_uncropped/scallop for 224.png/txt
# Unable To Copy dataset_uncropped/scallop for 1193.png/txt
# Unable To Copy dataset_uncropped/scallop for 379.png/txt
# Unable To Copy dataset_uncropped/scallop for 1311.png/txt
# Unable To Copy dataset_uncropped/scallop for 354.png/txt
# Unable To Copy dataset_uncropped/scallop for 197.png/txt
# Unable To Copy dataset_uncropped/scallop for 1421.png/txt
# Unable To Copy dataset_uncropped/scallop for 1120.png/txt
# Unable To Copy dataset_uncropped/scallop for 875.png/txt
# Unable To Copy dataset_uncropped/scallop for 410.png/txt
# Unable To Copy dataset_uncropped/scallop for 43.png/txt
# Unable To Copy dataset_uncropped/scallop for 235.png/txt
# Unable To Copy dataset_uncropped/scallop for 1211.png/txt
# Unable To Copy dataset_uncropped/scallop for 1017.png/txt
# Unable To Copy dataset_uncropped/scallop for 999.png/txt
# Unable To Copy dataset_uncropped/scallop for 1029.png/txt
# Unable To Copy dataset_uncropped/scallop for 355.png/txt
# Unable To Copy dataset_uncropped/scallop for 319.png/txt
# Unable To Copy dataset_uncropped/scallop for 23.png/txt
# Unable To Copy dataset_uncropped/scallop for 391.png/txt
# Unable To Copy dataset_uncropped/scallop for 501.png/txt
# Unable To Copy dataset_uncropped/scallop for 1092.png/txt
# Unable To Copy dataset_uncropped/scallop for 621.png/txt
# Unable To Copy dataset_uncropped/scallop for 1232.png/txt
# Unable To Copy dataset_uncropped/scallop for 222.png/txt
# Unable To Copy dataset_uncropped/scallop for 516.png/txt
# Unable To Copy dataset_uncropped/scallop for 293.png/txt
# Unable To Copy dataset_uncropped/scallop for 582.png/txt
# Unable To Copy dataset_uncropped/scallop for 66.png/txt
# Unable To Copy dataset_uncropped/scallop for 1219.png/txt
# Unable To Copy dataset_uncropped/scallop for 1333.png/txt
# Unable To Copy dataset_uncropped/scallop for 476.png/txt
# Unable To Copy dataset_uncropped/scallop for 1371.png/txt
# Unable To Copy dataset_uncropped/scallop for 321.png/txt
# Unable To Copy dataset_uncropped/scallop for 7.png/txt
# Unable To Copy dataset_uncropped/scallop for 626.png/txt
# Unable To Copy dataset_uncropped/scallop for 93.png/txt
# Unable To Copy dataset_uncropped/scallop for 985.png/txt
# Unable To Copy dataset_uncropped/scallop for 500.png/txt
# Unable To Copy dataset_uncropped/scallop for 1300.png/txt
# Unable To Copy dataset_uncropped/scallop for 511.png/txt
# Unable To Copy dataset_uncropped/scallop for 1100.png/txt
# Unable To Copy dataset_uncropped/scallop for 497.png/txt
# Unable To Copy dataset_uncropped/scallop for 1327.png/txt
# Unable To Copy dataset_uncropped/scallop for 763.png/txt
# Unable To Copy dataset_uncropped/scallop for 942.png/txt
# Unable To Copy dataset_uncropped/scallop for 404.png/txt
# Unable To Copy dataset_uncropped/scallop for 659.png/txt
# Unable To Copy dataset_uncropped/scallop for 1047.png/txt
# Unable To Copy dataset_uncropped/scallop for 72.png/txt
# Unable To Copy dataset_uncropped/scallop for 189.png/txt
# Unable To Copy dataset_uncropped/scallop for 527.png/txt
# Unable To Copy dataset_uncropped/scallop for 468.png/txt
# Unable To Copy dataset_uncropped/scallop for 300.png/txt
# Unable To Copy dataset_uncropped/scallop for 244.png/txt
# Unable To Copy dataset_uncropped/scallop for 1407.png/txt
# Unable To Copy dataset_uncropped/scallop for 1202.png/txt
# Unable To Copy dataset_uncropped/scallop for 27.png/txt
# Unable To Copy dataset_uncropped/scallop for 928.png/txt
# Unable To Copy dataset_uncropped/scallop for 773.png/txt
# Unable To Copy dataset_uncropped/scallop for 1366.png/txt
# Unable To Copy dataset_uncropped/scallop for 1341.png/txt
# Unable To Copy dataset_uncropped/scallop for 1102.png/txt
# Unable To Copy dataset_uncropped/scallop for 164.png/txt
# Unable To Copy dataset_uncropped/scallop for 688.png/txt
# Unable To Copy dataset_uncropped/scallop for 219.png/txt
# Unable To Copy dataset_uncropped/scallop for 584.png/txt
# Unable To Copy dataset_uncropped/scallop for 417.png/txt
# Unable To Copy dataset_uncropped/scallop for 1237.png/txt
# Unable To Copy dataset_uncropped/scallop for 798.png/txt
# Unable To Copy dataset_uncropped/scallop for 345.png/txt
# Unable To Copy dataset_uncropped/scallop for 1091.png/txt
# Unable To Copy dataset_uncropped/scallop for 757.png/txt
# Unable To Copy dataset_uncropped/scallop for 1162.png/txt
# Unable To Copy dataset_uncropped/scallop for 699.png/txt
# Unable To Copy dataset_uncropped/scallop for 1114.png/txt
# Unable To Copy dataset_uncropped/scallop for 955.png/txt
# Unable To Copy dataset_uncropped/scallop for 965.png/txt
# Unable To Copy dataset_uncropped/scallop for 1224.png/txt
# Unable To Copy dataset_uncropped/scallop for 1042.png/txt
# Unable To Copy dataset_uncropped/scallop for 486.png/txt
# Unable To Copy dataset_uncropped/scallop for 1270.png/txt
# Unable To Copy dataset_uncropped/scallop for 405.png/txt
# Unable To Copy dataset_uncropped/scallop for 160.png/txt
# Unable To Copy dataset_uncropped/scallop for 1361.png/txt
# Unable To Copy dataset_uncropped/scallop for 1267.png/txt
# Unable To Copy dataset_uncropped/scallop for 275.png/txt
# Unable To Copy dataset_uncropped/scallop for 1425.png/txt
# Unable To Copy dataset_uncropped/scallop for 278.png/txt
# Unable To Copy dataset_uncropped/scallop for 840.png/txt
# Unable To Copy dataset_uncropped/scallop for 126.png/txt
# Unable To Copy dataset_uncropped/scallop for 616.png/txt
# Unable To Copy dataset_uncropped/dead-scallop for 16.png/txt
# Unable To Copy dataset_uncropped/dead-scallop for 13.png/txt
# Unable To Copy dataset_uncropped/dead-scallop for 29.png/txt
# Unable To Copy dataset_uncropped/dead-scallop for 15.png/txt
# Unable To Copy dataset_uncropped/dead-scallop for 38.png/txt
# Unable To Copy dataset_uncropped/dead-scallop for 62.png/txt
# Unable To Copy dataset_uncropped/dead-scallop for 26.png/txt
# Unable To Copy dataset_uncropped/dead-scallop for 64.png/txt
# Unable To Copy dataset_uncropped/dead-scallop for 12.png/txt
# Unable To Copy dataset_uncropped/dead-scallop for 51.png/txt
# Unable To Copy dataset_uncropped/dead-scallop for 65.png/txt
# Unable To Copy dataset_uncropped/dead-scallop for 68.png/txt
# Unable To Copy dataset_uncropped/dead-scallop for 41.png/txt
# Unable To Copy dataset_uncropped/dead-scallop for 2.png/txt
# Unable To Copy dataset_uncropped/dead-scallop for 22.png/txt
# Unable To Copy dataset_uncropped/dead-scallop for 1.png/txt
# Unable To Copy dataset_uncropped/dead-scallop for 23.png/txt
# Unable To Copy dataset_uncropped/dead-scallop for 37.png/txt
# Unable To Copy dataset_uncropped/dead-scallop for 21.png/txt
# Unable To Copy dataset_uncropped/skate for 273.png/txt
# Unable To Copy dataset_uncropped/skate for 369.png/txt
# Unable To Copy dataset_uncropped/skate for 488.png/txt
# Unable To Copy dataset_uncropped/skate for 69.png/txt
# Unable To Copy dataset_uncropped/skate for 155.png/txt
# Unable To Copy dataset_uncropped/skate for 484.png/txt
# Unable To Copy dataset_uncropped/skate for 522.png/txt
# Unable To Copy dataset_uncropped/skate for 641.png/txt
# Unable To Copy dataset_uncropped/skate for 215.png/txt
# Unable To Copy dataset_uncropped/skate for 280.png/txt
# Unable To Copy dataset_uncropped/skate for 563.png/txt
# Unable To Copy dataset_uncropped/skate for 412.png/txt
# Unable To Copy dataset_uncropped/skate for 465.png/txt
# Unable To Copy dataset_uncropped/skate for 492.png/txt
# Unable To Copy dataset_uncropped/skate for 319.png/txt
# Unable To Copy dataset_uncropped/skate for 307.png/txt
# Unable To Copy dataset_uncropped/skate for 14.png/txt
# Unable To Copy dataset_uncropped/skate for 55.png/txt
# Unable To Copy dataset_uncropped/skate for 416.png/txt
# Unable To Copy dataset_uncropped/skate for 105.png/txt
# Unable To Copy dataset_uncropped/skate for 328.png/txt
# Unable To Copy dataset_uncropped/skate for 294.png/txt
# Unable To Copy dataset_uncropped/skate for 321.png/txt
# Unable To Copy dataset_uncropped/skate for 469.png/txt
# Unable To Copy dataset_uncropped/skate for 3.png/txt
# Unable To Copy dataset_uncropped/skate for 417.png/txt
# Unable To Copy dataset_uncropped/skate for 180.png/txt
# Unable To Copy dataset_uncropped/skate for 558.png/txt
# Unable To Copy dataset_uncropped/skate for 140.png/txt
# Unable To Copy dataset_uncropped/skate for 225.png/txt
# Unable To Copy dataset_uncropped/flounder for 128.png/txt
# Unable To Copy dataset_uncropped/flounder for 101.png/txt
# Unable To Copy dataset_uncropped/flounder for 308.png/txt
# Unable To Copy dataset_uncropped/flounder for 120.png/txt
# Unable To Copy dataset_uncropped/flounder for 181.png/txt
# Unable To Copy dataset_uncropped/flounder for 83.png/txt
# Unable To Copy dataset_uncropped/flounder for 224.png/txt
# Unable To Copy dataset_uncropped/flounder for 146.png/txt
# Unable To Copy dataset_uncropped/flounder for 287.png/txt
# Unable To Copy dataset_uncropped/flounder for 398.png/txt
# Unable To Copy dataset_uncropped/flounder for 57.png/txt
# Unable To Copy dataset_uncropped/flounder for 90.png/txt
# Unable To Copy dataset_uncropped/flounder for 183.png/txt
# Unable To Copy dataset_uncropped/flounder for 356.png/txt
# Unable To Copy dataset_uncropped/flounder for 387.png/txt
# Unable To Copy dataset_uncropped/flounder for 106.png/txt
# Unable To Copy dataset_uncropped/flounder for 201.png/txt
# Unable To Copy dataset_uncropped/flounder for 111.png/txt
# Unable To Copy dataset_uncropped/flounder for 228.png/txt
# Unable To Copy dataset_uncropped/flounder for 380.png/txt
# Unable To Copy dataset_uncropped/flounder for 66.png/txt
# Unable To Copy dataset_uncropped/flounder for 289.png/txt
# Unable To Copy dataset_uncropped/flounder for 399.png/txt
# Unable To Copy dataset_uncropped/flounder for 392.png/txt
# Unable To Copy dataset_uncropped/flounder for 259.png/txt
# Unable To Copy dataset_uncropped/flounder for 118.png/txt
# Unable To Copy dataset_uncropped/flounder for 161.png/txt
# Unable To Copy dataset_uncropped/flounder for 344.png/txt
# Unable To Copy dataset_uncropped/flounder for 147.png/txt
# Unable To Copy dataset_uncropped/flounder for 262.png/txt
# Unable To Copy dataset_uncropped/flounder for 189.png/txt
# Unable To Copy dataset_uncropped/flounder for 139.png/txt
# Unable To Copy dataset_uncropped/flounder for 6.png/txt
# Unable To Copy dataset_uncropped/flounder for 385.png/txt
# Unable To Copy dataset_uncropped/flounder for 353.png/txt
# Unable To Copy dataset_uncropped/flounder for 286.png/txt
# Unable To Copy dataset_uncropped/flounder for 272.png/txt
# Unable To Copy dataset_uncropped/flounder for 423.png/txt
# Unable To Copy dataset_uncropped/flounder for 81.png/txt
# Unable To Copy dataset_uncropped/roundfish for 2082.png/txt
# Unable To Copy dataset_uncropped/roundfish for 2182.png/txt
# Unable To Copy dataset_uncropped/roundfish for 2220.png/txt
# Unable To Copy dataset_uncropped/roundfish for 2153.png/txt
# Unable To Copy dataset_uncropped/roundfish for 962.png/txt
# Unable To Copy dataset_uncropped/roundfish for 53.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1266.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1356.png/txt
# Unable To Copy dataset_uncropped/roundfish for 909.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1608.png/txt
# Unable To Copy dataset_uncropped/roundfish for 219.png/txt
# Unable To Copy dataset_uncropped/roundfish for 2218.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1854.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1705.png/txt
# Unable To Copy dataset_uncropped/roundfish for 897.png/txt
# Unable To Copy dataset_uncropped/roundfish for 666.png/txt
# Unable To Copy dataset_uncropped/roundfish for 757.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1739.png/txt
# Unable To Copy dataset_uncropped/roundfish for 193.png/txt
# Unable To Copy dataset_uncropped/roundfish for 656.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1058.png/txt
# Unable To Copy dataset_uncropped/roundfish for 212.png/txt
# Unable To Copy dataset_uncropped/roundfish for 729.png/txt
# Unable To Copy dataset_uncropped/roundfish for 138.png/txt
# Unable To Copy dataset_uncropped/roundfish for 2145.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1378.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1936.png/txt
# Unable To Copy dataset_uncropped/roundfish for 905.png/txt
# Unable To Copy dataset_uncropped/roundfish for 2207.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1403.png/txt
# Unable To Copy dataset_uncropped/roundfish for 469.png/txt
# Unable To Copy dataset_uncropped/roundfish for 254.png/txt
# Unable To Copy dataset_uncropped/roundfish for 625.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1144.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1059.png/txt
# Unable To Copy dataset_uncropped/roundfish for 2275.png/txt
# Unable To Copy dataset_uncropped/roundfish for 2046.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1735.png/txt
# Unable To Copy dataset_uncropped/roundfish for 15.png/txt
# Unable To Copy dataset_uncropped/roundfish for 95.png/txt
# Unable To Copy dataset_uncropped/roundfish for 470.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1211.png/txt
# Unable To Copy dataset_uncropped/roundfish for 272.png/txt
# Unable To Copy dataset_uncropped/roundfish for 332.png/txt
# Unable To Copy dataset_uncropped/roundfish for 778.png/txt
# Unable To Copy dataset_uncropped/roundfish for 680.png/txt
# Unable To Copy dataset_uncropped/roundfish for 146.png/txt
# Unable To Copy dataset_uncropped/roundfish for 305.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1270.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1048.png/txt
# Unable To Copy dataset_uncropped/roundfish for 675.png/txt
# Unable To Copy dataset_uncropped/roundfish for 289.png/txt
# Unable To Copy dataset_uncropped/roundfish for 294.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1544.png/txt
# Unable To Copy dataset_uncropped/roundfish for 913.png/txt
# Unable To Copy dataset_uncropped/roundfish for 223.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1216.png/txt
# Unable To Copy dataset_uncropped/roundfish for 741.png/txt
# Unable To Copy dataset_uncropped/roundfish for 2251.png/txt
# Unable To Copy dataset_uncropped/roundfish for 492.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1966.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1167.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1156.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1919.png/txt
# Unable To Copy dataset_uncropped/roundfish for 597.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1917.png/txt
# Unable To Copy dataset_uncropped/roundfish for 551.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1654.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1050.png/txt
# Unable To Copy dataset_uncropped/roundfish for 2331.png/txt
# Unable To Copy dataset_uncropped/roundfish for 235.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1830.png/txt
# Unable To Copy dataset_uncropped/roundfish for 476.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1641.png/txt
# Unable To Copy dataset_uncropped/roundfish for 2141.png/txt
# Unable To Copy dataset_uncropped/roundfish for 786.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1554.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1256.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1591.png/txt
# Unable To Copy dataset_uncropped/roundfish for 595.png/txt
# Unable To Copy dataset_uncropped/roundfish for 555.png/txt
# Unable To Copy dataset_uncropped/roundfish for 2070.png/txt
# Unable To Copy dataset_uncropped/roundfish for 2149.png/txt
# Unable To Copy dataset_uncropped/roundfish for 413.png/txt
# Unable To Copy dataset_uncropped/roundfish for 248.png/txt
# Unable To Copy dataset_uncropped/roundfish for 2264.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1093.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1364.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1123.png/txt
# Unable To Copy dataset_uncropped/roundfish for 829.png/txt
# Unable To Copy dataset_uncropped/roundfish for 1501.png/txt
